# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
#Import Orders products merged
ords_prods_merge = pd.read_pickle(r'/Users/winsontom/Desktop/10-2023 Instacart Basket Analysis/02 Data /Prepared Data/orders_products_merged.pkl')

# %%
#Only work with 1 million rows per task

df = ords_prods_merge[:1000000]

# %%
df
# Out:
#         Unnamed: 0_x  order_id  user_id  order_number  order_dow  \
# 0                  0   2539329        1             1          2
# 1                  0   2539329        1             1          2
# 2                  0   2539329        1             1          2
# 3                  0   2539329        1             1          2
# 4                  0   2539329        1             1          2
# ...              ...       ...      ...           ...        ...
# 999995        106885   3264026     6467            54          6
# 999996        106886   2845775     6467            55          3
# 999997        106886   2845775     6467            55          3
# 999998        106886   2845775     6467            55          3
# 999999        106886   2845775     6467            55          3
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 0                       8                     NaN         196
# ...

# %%
#Created function to create price label

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#Creating a price label column; data put into 1 which is rows. 

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/yj/v30db1v90zs0p0pvttp796cm0000gp/T/ipykernel_94791/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
#Value count of the  different ranges, drop it if NA
#Mid Range products are most common

df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    672525
# Low-range product    314109
# High range            12413
# Not enough data         953
# Name: count, dtype: int64

# %%
#Maximum price

df['prices'].max()
# Out:
# 99999.0

# %%
#Using Loc to define the high range products. Locate - prices column - value more than 15, then in price range loc put it in as high range product
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/yj/v30db1v90zs0p0pvttp796cm0000gp/T/ipykernel_94791/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# /var/folders/yj/v30db1v90zs0p0pvttp796cm0000gp/T/ipykernel_94791/1169838859.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'High-range product' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
#Defining mid range product values for DF
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
##Defining low range product values for DF
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Apply the LOC method to full data not just 1 million rows

ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/yj/v30db1v90zs0p0pvttp796cm0000gp/T/ipykernel_94791/1225137091.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'High-range product' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
#Apply the LOC method to full data - Mid range
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
#Apply the LOC method to full data - Low range

ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Tracking which day of the week has the most orders. 0 = Saturday. 

ords_prods_merge['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6209808
# 1    5665951
# 6    4500391
# 2    4217868
# 5    4209603
# 3    3844175
# 4    3787263
# Name: count, dtype: int64

# %%
#New column that identifies if it is busiest, least busy, regularly busy

result = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
#Counting what occurs the most, 
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22437988
# Busiest day        6209808
# Least busy         3787263
# Name: count, dtype: int64

# %%
ords_prods_merge
# Out:
#           Unnamed: 0_x  order_id  user_id  order_number  order_dow  \
# 0                    0   2539329        1             1          2
# 1                    0   2539329        1             1          2
# 2                    0   2539329        1             1          2
# 3                    0   2539329        1             1          2
# 4                    0   2539329        1             1          2
# ...                ...       ...      ...           ...        ...
# 32435054       3421081   2977660   206209            13          1
# 32435055       3421081   2977660   206209            13          1
# 32435056       3421081   2977660   206209            13          1
# 32435057       3421081   2977660   206209            13          1
# 32435058       3421081   2977660   206209            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...
